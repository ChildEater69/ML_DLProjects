# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd
query = "narendramodi until:2023-02-10 since:2023-01-01"
tweets = []
limit = 2000
for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    
    # print(vars(tweet))
    # break
    if len(tweets) == limit:
        break
    else:
        tweets.append([tweet.date, tweet.user.username, tweet.content,tweet.likeCount])
        tweets.append([tweet.date, tweet.username, tweet.content,tweet.likeCount])

df = pd.DataFrame(tweets, columns=['Date', 'User', 'Tweet','Like'])
print(df)
# to save to csv
# df.to_csv('tweets.csv')
# Out:
# C:\Users\Acer pc\AppData\Local\Temp\ipykernel_16488\3326344039.py:13: FutureWarning: content is deprecated, use rawContent instead
#   tweets.append([tweet.date, tweet.user.username, tweet.content,tweet.likeCount])
# C:\Users\Acer pc\AppData\Local\Temp\ipykernel_16488\3326344039.py:14: FutureWarning: username is deprecated, use user.username instead
#   tweets.append([tweet.date, tweet.username, tweet.content,tweet.likeCount])
# C:\Users\Acer pc\AppData\Local\Temp\ipykernel_16488\3326344039.py:14: FutureWarning: content is deprecated, use rawContent instead
#   tweets.append([tweet.date, tweet.username, tweet.content,tweet.likeCount])
#                           Date             User  \
# 0    2023-02-09 23:59:57+00:00  Bhagwat81527073
# 1    2023-02-09 23:59:57+00:00  Bhagwat81527073
# 2    2023-02-09 23:59:52+00:00      shaswatd880
# 3    2023-02-09 23:59:52+00:00      shaswatd880
# 4    2023-02-09 23:59:48+00:00        PDasaraju
# ...                        ...              ...
# ...

# %%
df['Time'],df['Date']= df['Date'].apply(lambda x:x.time()), df['Date'].apply(lambda x:x.date())
df
# Out:
#             Date             User  \
# 0     2023-02-09  Bhagwat81527073
# 1     2023-02-09  Bhagwat81527073
# 2     2023-02-09      shaswatd880
# 3     2023-02-09      shaswatd880
# 4     2023-02-09        PDasaraju
# ...          ...              ...
# 1995  2023-02-09  singhanjalivik1
# 1996  2023-02-09  Satveer67782291
# 1997  2023-02-09  Satveer67782291
# 1998  2023-02-09      JaypalMohit
# 1999  2023-02-09      JaypalMohit
#
#                                                   Tweet  Like  RT      Time
# 0     @AMISHDEVGAN @narendramodi सोशल मीडिया से लेकर...     0   0  23:59:57
# 1     @AMISHDEVGAN @narendramodi सोशल मीडिया से लेकर...     0   0  23:59:57
# 2     @RamPawarHindu1 @AmanChopra_ @narendramodi अंध...     0   0  23:59:52
# 3     @RamPawarHindu1 @AmanChopra_ @narendramodi अंध...     0   0  23:59:52
# 4     देश के लिए जीता हूं। \n\n#PMModiInParliament\n...     1   0  23:59:48
# ...                                                 ...   ...  ..       ...
# ...

# %%
df.columns
# Out:
# Index(['Date', 'User', 'Tweet', 'Like'], dtype='object')

# %%
df.shape
# Out:
# (2000, 4)

# %%
import pandas as pd
import re
from nltk.corpus import stopwords
from textblob import TextBlob

# %%
stop_words = set(stopwords.words('english'))
stop_words
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
# ...

# %%
love_words = ['love', 'support', 'like', 'admire', 'respect']
love_words
# Out:
# ['love', 'support', 'like', 'admire', 'respect']

# %%
hate_words = ['hate', 'dislike', 'disapprove', 'condemn']
hate_words
# Out:
# ['hate', 'dislike', 'disapprove', 'condemn']
