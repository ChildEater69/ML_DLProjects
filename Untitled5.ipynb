# %%
#Importing Libraries

import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv(r"C:\Users\Acer pc\Downloads\archive (13)\Brain Tumor.csv")

# %% [markdown]
# DATASET

# %%
df.head()
# Out:
#     Image  Class      Mean     Variance  Standard Deviation   Entropy  \
# 0  Image1      0  6.535339   619.587845           24.891522  0.109059
# 1  Image2      0  8.749969   805.957634           28.389393  0.266538
# 2  Image3      1  7.341095  1143.808219           33.820234  0.001467
# 3  Image4      1  5.958145   959.711985           30.979219  0.001477
# 4  Image5      0  7.315231   729.540579           27.010009  0.146761
#
#    Skewness   Kurtosis    Contrast    Energy       ASM  Homogeneity  \
# 0  4.276477  18.900575   98.613971  0.293314  0.086033     0.530941
# 1  3.718116  14.464618   63.858816  0.475051  0.225674     0.651352
# 2  5.061750  26.479563   81.867206  0.031917  0.001019     0.268275
# 3  5.677977  33.428845  151.229741  0.032024  0.001026     0.243851
# 4  4.283221  19.079108  174.988756  0.343849  0.118232     0.501140
#
#    Dissimilarity  Correlation     Coarseness
# 0       4.473346     0.981939  7.458341e-155
# ...

# %%
df.tail()
# Out:
#           Image  Class       Mean     Variance  Standard Deviation   Entropy  \
# 3757  Image3758      0  21.234512  1208.850174           34.768523  0.063774
# 3758  Image3759      0  20.435349  1227.151440           35.030721  0.066763
# 3759  Image3760      0  18.011520  1151.582765           33.934978  0.068396
# 3760  Image3761      0  13.330429   945.732779           30.752769  0.087872
# 3761  Image3762      0   6.110138   480.884025           21.929068  0.118171
#
#       Skewness   Kurtosis    Contrast    Energy       ASM  Homogeneity  \
# 3757  2.082079   4.647310  158.437600  0.220666  0.048693     0.487131
# 3758  2.144625   4.882034  161.158675  0.225931  0.051045     0.502712
# 3759  2.308349   5.579498  167.130118  0.228930  0.052409     0.492269
# 3760  2.732822   7.757570  223.812932  0.261527  0.068397     0.480064
# 3761  4.110669  17.538826  239.251388  0.306224  0.093773     0.494333
#
#       Dissimilarity  Correlation     Coarseness
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3762 entries, 0 to 3761
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Image               3762 non-null   object
#  1   Class               3762 non-null   int64
#  2   Mean                3762 non-null   float64
#  3   Variance            3762 non-null   float64
#  4   Standard Deviation  3762 non-null   float64
#  5   Entropy             3762 non-null   float64
#  6   Skewness            3762 non-null   float64
#  7   Kurtosis            3762 non-null   float64
#  8   Contrast            3762 non-null   float64
#  9   Energy              3762 non-null   float64
#  10  ASM                 3762 non-null   float64
#  11  Homogeneity         3762 non-null   float64
#  12  Dissimilarity       3762 non-null   float64
#  13  Correlation         3762 non-null   float64
#  14  Coarseness          3762 non-null   float64
# ...

# %%
df.describe()
# Out:
#              Class         Mean     Variance  Standard Deviation      Entropy  \
# count  3762.000000  3762.000000  3762.000000         3762.000000  3762.000000
# mean      0.447368     9.488890   711.101063           25.182271     0.073603
# std       0.497288     5.728022   467.466896            8.773526     0.070269
# min       0.000000     0.078659     3.145628            1.773592     0.000882
# 25%       0.000000     4.982395   363.225459           19.058475     0.006856
# 50%       0.000000     8.477531   622.580417           24.951560     0.066628
# 75%       1.000000    13.212723   966.954319           31.095889     0.113284
# max       1.000000    33.239975  2910.581879           53.949809     0.394539
#
#           Skewness     Kurtosis     Contrast       Energy          ASM  \
# count  3762.000000  3762.000000  3762.000000  3762.000000  3762.000000
# mean      4.102727    24.389071   127.961459     0.204705     0.058632
# ...

# %%
df.shape
# Out:
# (3762, 15)

# %% [markdown]
# DATA CLEANSING

# %% [markdown]
# Handeling Missing Values

# %%
df.isnull().sum()
# Out:
# Image                 0
# Class                 0
# Mean                  0
# Variance              0
# Standard Deviation    0
# Entropy               0
# Skewness              0
# Kurtosis              0
# Contrast              0
# Energy                0
# ASM                   0
# Homogeneity           0
# Dissimilarity         0
# Correlation           0
# Coarseness            0
# dtype: int64

# %% [markdown]
# OUTLIER DETECTION

# %%
plt.boxplot(df.Mean)
Q1 = df.Mean.quantile(0.25)
Q3 = df.Mean.quantile(0.75)
IQR = Q3 - Q1
df = df[(df.Mean >= Q1 - 1.5*IQR) & (df.Mean <= Q3 + 1.5*IQR)]

# %%
df.shape
# Out:
# (3728, 15)

# %%
plt.boxplot(df.Variance)
Q1 = df.Variance.quantile(0.25)
Q3 = df.Variance.quantile(0.75)
IQR = Q3 - Q1
df = df[(df.Variance >= Q1 - 1.5*IQR) & (df.Variance <= Q3 + 1.5*IQR)]

# %%
df.shape
# Out:
# (3654, 15)

# %%
plt.boxplot(df.Entropy)
Q1 = df.Entropy.quantile(0.25)
Q3 = df.Entropy.quantile(0.75)
IQR = Q3 - Q1
df = df[(df.Entropy >= Q1 - 1.5*IQR) & (df.Entropy <= Q3 + 1.5*IQR)]

# %%
df.shape
# Out:
# (3615, 15)

# %%
plt.boxplot(df.Skewness )
Q1 = df.Skewness .quantile(0.25)
Q3 = df.Skewness .quantile(0.75)
IQR = Q3 - Q1
df = df[(df.Skewness  >= Q1 - 1.5*IQR) & (df.Skewness  <= Q3 + 1.5*IQR)]

# %%
df.shape
# Out:
# (3395, 15)

# %%
plt.boxplot(df.Skewness)
Q1 = df.Skewness .quantile(0.25)
Q3 = df.Skewness .quantile(0.75)
IQR = Q3 - Q1
df = df[(df.Skewness  >= Q1 - 1.5*IQR) & (df.Skewness  <= Q3 + 1.5*IQR)]

# %%
df.shape
# Out:
# (3330, 15)

# %%
plt.boxplot(df.Contrast)
Q1 = df.Contrast.quantile(0.25)
Q3 = df.Contrast.quantile(0.75)
IQR = Q3 - Q1
df = df[(df.Contrast >= Q1 - 1.5*IQR) & (df.Contrast  <= Q3 + 1.5*IQR)]

# %%
df.shape
# Out:
# (3228, 15)

# %%
plt.boxplot(df.ASM)
Q1 = df.ASM.quantile(0.25)
Q3 = df.ASM.quantile(0.75)
IQR = Q3 - Q1
df = df[(df.ASM >= Q1 - 1.5*IQR) & (df.ASM  <= Q3 + 1.5*IQR)]

# %%
df.shape
# Out:
# (3204, 15)

# %%
plt.boxplot(df.Dissimilarity)
Q1 = df.Dissimilarity.quantile(0.25)
Q3 = df.Dissimilarity.quantile(0.75)
IQR = Q3 - Q1
df = df[(df.Dissimilarity >= Q1 - 1.5*IQR) & (df.Dissimilarity  <= Q3 + 1.5*IQR)]

# %%
df.shape
# Out:
# (3192, 15)

# %%
df = df.reset_index()
df = df.drop(['index'], axis = 1)
df
# Out:
#           Image  Class       Mean     Variance  Standard Deviation   Entropy  \
# 0        Image1      0   6.535339   619.587845           24.891522  0.109059
# 1        Image3      1   7.341095  1143.808219           33.820234  0.001467
# 2        Image4      1   5.958145   959.711985           30.979219  0.001477
# 3        Image5      0   7.315231   729.540579           27.010009  0.146761
# 4        Image6      0   7.524109   607.395258           24.645390  0.214086
# ...         ...    ...        ...          ...                 ...       ...
# 3187  Image3758      0  21.234512  1208.850174           34.768523  0.063774
# 3188  Image3759      0  20.435349  1227.151440           35.030721  0.066763
# 3189  Image3760      0  18.011520  1151.582765           33.934978  0.068396
# 3190  Image3761      0  13.330429   945.732779           30.752769  0.087872
# 3191  Image3762      0   6.110138   480.884025           21.929068  0.118171
#
# ...

# %%
# Checking the Duplicates Records
df.drop_duplicates()
# Out:
#           Image  Class       Mean     Variance  Standard Deviation   Entropy  \
# 0        Image1      0   6.535339   619.587845           24.891522  0.109059
# 1        Image3      1   7.341095  1143.808219           33.820234  0.001467
# 2        Image4      1   5.958145   959.711985           30.979219  0.001477
# 3        Image5      0   7.315231   729.540579           27.010009  0.146761
# 4        Image6      0   7.524109   607.395258           24.645390  0.214086
# ...         ...    ...        ...          ...                 ...       ...
# 3187  Image3758      0  21.234512  1208.850174           34.768523  0.063774
# 3188  Image3759      0  20.435349  1227.151440           35.030721  0.066763
# 3189  Image3760      0  18.011520  1151.582765           33.934978  0.068396
# 3190  Image3761      0  13.330429   945.732779           30.752769  0.087872
# 3191  Image3762      0   6.110138   480.884025           21.929068  0.118171
#
# ...

# %%
'''plt.figure(figsize=(15,15))
sns.heatmap(df.corr(),color = "k", annot=True)'''



path_list = []
base_path = r"C:\Users\Acer pc\Downloads\archive (13)\Brain Tumor\Brain Tumor"
for entry in os.listdir(base_path):
    path_list.append( os.path.join(base_path,entry))
 


pathes_dict={os.path.splitext(os.path.basename(x))[0]: x for x in path_list}
df['pathes'] = df['Image'].map(pathes_dict.get)


for x in range (0 ,9):
    img =plt.imread(df['pathes'][x])
    plt.imshow(img)
    plt.subplot(3,3,x+1)

# %%
df
# Out:
#           Image  Class       Mean     Variance  Standard Deviation   Entropy  \
# 0        Image1      0   6.535339   619.587845           24.891522  0.109059
# 1        Image3      1   7.341095  1143.808219           33.820234  0.001467
# 2        Image4      1   5.958145   959.711985           30.979219  0.001477
# 3        Image5      0   7.315231   729.540579           27.010009  0.146761
# 4        Image6      0   7.524109   607.395258           24.645390  0.214086
# ...         ...    ...        ...          ...                 ...       ...
# 3187  Image3758      0  21.234512  1208.850174           34.768523  0.063774
# 3188  Image3759      0  20.435349  1227.151440           35.030721  0.066763
# 3189  Image3760      0  18.011520  1151.582765           33.934978  0.068396
# 3190  Image3761      0  13.330429   945.732779           30.752769  0.087872
# 3191  Image3762      0   6.110138   480.884025           21.929068  0.118171
#
# ...
