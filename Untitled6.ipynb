# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\Acer pc\Downloads\archive (2)\WinnipegDataset.txt')
df
# Out:
#         label        f1       f2        f3        f4        f5        f6  \
# 0           1 -13.55900 -21.4070 -11.40400 -15.24800 -11.92300 -15.29100
# 1           1 -12.80200 -20.3350 -10.39900 -14.13200 -11.09600 -14.36100
# 2           1 -12.43100 -19.9020 -10.07400 -13.59800 -10.82900 -14.04800
# 3           1 -12.68900 -19.5290 -10.02800 -13.35000 -11.05600 -14.01400
# 4           1 -12.68600 -19.2780  -9.81850 -13.10800 -10.93200 -13.93900
# ...       ...       ...      ...       ...       ...       ...       ...
# 325829      7   2.48230  -7.6870   1.07950   0.74318  -0.94070   0.90493
# 325830      7   2.52340  -7.6745   1.08680   0.76189  -0.91177   0.93663
# 325831      7  -1.92700 -11.4160  -2.43540  -3.45370  -4.15130  -3.48100
# 325832      7   0.12483 -10.1440  -0.62193  -1.54210  -2.31000  -1.52500
# 325833      7   0.20063 -10.0500  -0.59892  -1.50120  -2.25060  -1.46320
#
#              f7       f8       f9  ...     f165      f166    f167       f168  \
# ...

# %%
df.head()
# Out:
#    label      f1      f2       f3      f4      f5      f6      f7      f8  \
# 0      1 -13.559 -21.407 -11.4040 -15.248 -11.923 -15.291 -2.1548 -7.8474
# 1      1 -12.802 -20.335 -10.3990 -14.132 -11.096 -14.361 -2.4039 -7.5330
# 2      1 -12.431 -19.902 -10.0740 -13.598 -10.829 -14.048 -2.3566 -7.4717
# 3      1 -12.689 -19.529 -10.0280 -13.350 -11.056 -14.014 -2.6611 -6.8396
# 4      1 -12.686 -19.278  -9.8185 -13.108 -10.932 -13.939 -2.8675 -6.5919
#
#         f9  ...     f165     f166    f167      f168     f169     f170  \
# 0 -10.0020  ...  0.18519  0.72602  5.3333  6.000000  0.29489  9.77780
# 1  -9.9369  ...  0.33333 -0.48751  2.1111  0.098765  0.83333  0.33333
# 2  -9.8283  ...  0.25926  0.25298  2.2222  0.172840  0.68889  0.88889
# 3  -9.5006  ...  0.16049  0.43750  4.1111  0.320990  0.83333  0.33333
# 4  -9.4594  ...  0.18519  0.35000  4.0000  0.444440  0.68889  0.88889
#
#       f171     f172     f173     f174
# 0  2.44440  1.67700  0.20988  0.65422
# ...

# %%
df.shape
# Out:
# (325834, 175)
# (325834, 175)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 325834 entries, 0 to 325833
# Columns: 175 entries, label to f174
# dtypes: float64(169), int64(6)
# memory usage: 435.0 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 325834 entries, 0 to 325833
# Columns: 175 entries, label to f174
# dtypes: float64(169), int64(6)
# memory usage: 435.0 MB

# %%
df.describe()
# Out:
#                label             f1             f2             f3  \
# count  325834.000000  325834.000000  325834.000000  325834.000000
# mean        4.062421     -15.143602     -24.026035     -15.400034
# std         1.604617       3.504255       4.054214       3.267857
# min         1.000000     -23.971000     -34.308000     -23.161000
# 25%         3.000000     -17.848000     -27.119000     -17.563000
# 50%         4.000000     -15.992000     -25.064000     -16.164000
# 75%         6.000000     -11.786000     -20.387000     -13.427000
# max         7.000000       2.535600      -7.589100       1.104000
#
#                  f4             f5             f6             f7  \
# count  325834.00000  325834.000000  325834.000000  325834.000000
# mean      -18.59383     -14.493472     -18.427329       0.256432
# std         3.71163       3.189013       3.675741       1.682060
# min       -27.24500     -22.103000     -26.897000      -5.582600
# ...

# %%
df.corr()
# Out:
#           label        f1        f2        f3        f4        f5        f6  \
# label  1.000000 -0.644986 -0.644821 -0.748987 -0.726806 -0.672114 -0.739556
# f1    -0.644986  1.000000  0.959623  0.878904  0.940764  0.966871  0.937077
# f2    -0.644821  0.959623  1.000000  0.871976  0.939766  0.937634  0.927391
# f3    -0.748987  0.878904  0.871976  1.000000  0.946727  0.931361  0.942607
# f4    -0.726806  0.940764  0.939766  0.946727  1.000000  0.916543  0.987017
# ...         ...       ...       ...       ...       ...       ...       ...
# f170   0.038036  0.011096  0.019581  0.006901  0.010440  0.013582  0.005405
# f171   0.050327 -0.009695  0.001523 -0.014669 -0.011286 -0.004663 -0.018917
# f172   0.058235 -0.022247 -0.010552 -0.028708 -0.024264 -0.016849 -0.033668
# f173  -0.061464  0.024887  0.013447  0.032470  0.027487  0.019921  0.036999
# f174  -0.052463  0.018481  0.010665  0.024714  0.021900  0.014216  0.028422
#
# ...

# %%
sns.scatterplot(df["f1"],df["f2"])
plt.show()
sns.scatterplot(df["f1"],df["label"])
plt.show()
# Out:
# C:\Users\Acer pc\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Acer pc\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Acer pc\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
a=df['label'].to_string()

# %%
class_share=pd.Series(100*df.label.value_counts(normalize=True)).sort_index()
print("\nClass share \n")
for i in range(0,7):
    print(f'Class{class_share.index[i]}:{class_share.iloc[i]:.2f}%')
# Out:
# Class share
#
# Class2:1.10%
# Class3:23.22%
# Class4:22.73%
# Class5:14.46%
# Class6:26.11%
# Class7:0.35%
#
# Class share
#
# Class2:1.10%
# Class3:23.22%
# Class4:22.73%
# Class5:14.46%
# Class6:26.11%
# Class7:0.35%
